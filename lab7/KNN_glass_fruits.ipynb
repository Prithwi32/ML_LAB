# %%
#Just for ananlysis
import pandas as pd

df = pd.read_csv("fruits.csv")

print(df.info())  # Check data types and non-null counts
print(df.isnull().sum())  # Check missing data

X = df.drop(columns=['fruit_label'])
y = df['fruit_label']

# If X contains categorical data:
for col in X.columns:
    if X[col].dtype == 'object':
        X[col] = LabelEncoder().fit_transform(X[col])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
model.fit(X_train, y_train)  # Should work without error now
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB
# None
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
#Just for analysis
import pandas as pd

df = pd.read_csv("glass.csv")

print(df.info())  # Check data types and non-null counts
print(df.isnull().sum())  # Check missing data

X = df.drop(columns=['Type'])
y = df['Type']

# If X contains categorical data:
for col in X.columns:
    if X[col].dtype == 'object':
        X[col] = LabelEncoder().fit_transform(X[col])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.1)

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3, metric='euclidean')
model.fit(X_train, y_train)  # Should work without error now
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB
# None
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
#Main Code
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

def knn_experiment(data_path, target_column, splits=[0.1, 0.3], ks=[3,5,7], numeric_features=None):
    data = pd.read_csv(data_path)
    
    if numeric_features:
        X = data[numeric_features]
    else:
        X = data.drop(columns=[target_column])
    y = data[target_column]

    # Scale features for better KNN performance
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    for test_size in splits:
        print(f"\n\n---- Split: {100 - test_size*100:.0f}-{test_size*100:.0f} ----")
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=test_size, random_state=42)

        for k in ks:
            # Try Euclidean (p=2) and Manhattan (p=1) using minkowski metric
            for p_val, metric_name in [(2, 'euclidean'), (1, 'manhattan')]:
                model = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=p_val)
                model.fit(X_train, y_train)
                y_pred = model.predict(X_test)

                print(f"\nK={k}, Metric={metric_name}")
                print("Accuracy:", accuracy_score(y_test, y_pred))
                print("Report:\n", classification_report(y_test, y_pred, zero_division=0))

# Run for glass dataset (all features except 'Type' are numeric)
knn_experiment("glass.csv", "Type")

# Run for fruit dataset, specify only numeric features to avoid string columns
numeric_cols_fruits = ['mass', 'width', 'height', 'color_score']
knn_experiment("fruits.csv", "fruit_label", numeric_features=numeric_cols_fruits)
# Out:
# ---- Split: 90-10 ----
#
# K=3, Metric=euclidean
# Accuracy: 0.9545454545454546
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         8
#            5       1.00      1.00      1.00         2
#            6       1.00      0.67      0.80         3
#            7       0.80      1.00      0.89         4
#
#     accuracy                           0.95        22
#    macro avg       0.96      0.93      0.94        22
# weighted avg       0.96      0.95      0.95        22
#
#
# K=3, Metric=manhattan
# Accuracy: 0.8636363636363636
# Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.80      0.73         5
#            2       1.00      0.75      0.86         8
#            3       0.00      0.00      0.00         0
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         4
#
#     accuracy                           0.86        22
#    macro avg       0.78      0.76      0.76        22
# weighted avg       0.92      0.86      0.89        22
#
#
# K=5, Metric=euclidean
# Accuracy: 0.8181818181818182
# Report:
#                precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83         5
#            2       0.83      0.62      0.71         8
#            5       0.50      0.50      0.50         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         4
#
#     accuracy                           0.82        22
#    macro avg       0.81      0.82      0.81        22
# weighted avg       0.83      0.82      0.81        22
#
#
# K=5, Metric=manhattan
# Accuracy: 0.8636363636363636
# Report:
#                precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83         5
#            2       0.86      0.75      0.80         8
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         4
#
#     accuracy                           0.86        22
#    macro avg       0.91      0.85      0.86        22
# weighted avg       0.88      0.86      0.86        22
#
#
# K=7, Metric=euclidean
# Accuracy: 0.7727272727272727
# Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.80      0.73         5
#            2       0.75      0.75      0.75         8
#            5       1.00      0.50      0.67         2
#            6       1.00      0.67      0.80         3
#            7       0.80      1.00      0.89         4
#
#     accuracy                           0.77        22
#    macro avg       0.84      0.74      0.77        22
# weighted avg       0.80      0.77      0.77        22
#
#
# K=7, Metric=manhattan
# Accuracy: 0.8181818181818182
# Report:
#                precision    recall  f1-score   support
#
#            1       0.71      1.00      0.83         5
#            2       0.86      0.75      0.80         8
#            5       1.00      0.50      0.67         2
#            6       1.00      0.67      0.80         3
#            7       0.80      1.00      0.89         4
#
#     accuracy                           0.82        22
#    macro avg       0.87      0.78      0.80        22
# weighted avg       0.85      0.82      0.81        22
#
#
#
# ---- Split: 70-30 ----
#
# K=3, Metric=euclidean
# Accuracy: 0.6615384615384615
# Report:
#                precision    recall  f1-score   support
#
#            1       0.56      0.79      0.65        19
#            2       0.61      0.61      0.61        23
#            3       0.00      0.00      0.00         4
#            5       1.00      0.33      0.50         6
#            6       0.75      1.00      0.86         3
#            7       1.00      0.90      0.95        10
#
#     accuracy                           0.66        65
#    macro avg       0.65      0.61      0.59        65
# weighted avg       0.66      0.66      0.64        65
#
#
# K=3, Metric=manhattan
# Accuracy: 0.6923076923076923
# Report:
#                precision    recall  f1-score   support
#
#            1       0.62      0.84      0.71        19
#            2       0.61      0.61      0.61        23
#            3       1.00      0.25      0.40         4
#            5       1.00      0.33      0.50         6
#            6       0.75      1.00      0.86         3
#            7       1.00      0.90      0.95        10
#
#     accuracy                           0.69        65
#    macro avg       0.83      0.66      0.67        65
# weighted avg       0.74      0.69      0.68        65
#
#
# K=5, Metric=euclidean
# Accuracy: 0.6461538461538462
# Report:
#                precision    recall  f1-score   support
#
#            1       0.57      0.84      0.68        19
#            2       0.59      0.57      0.58        23
#            3       0.00      0.00      0.00         4
#            5       0.67      0.33      0.44         6
#            6       1.00      0.67      0.80         3
#            7       0.90      0.90      0.90        10
#
#     accuracy                           0.65        65
#    macro avg       0.62      0.55      0.57        65
# weighted avg       0.62      0.65      0.62        65
#
#
# K=5, Metric=manhattan
# Accuracy: 0.6923076923076923
# Report:
#                precision    recall  f1-score   support
#
#            1       0.61      0.89      0.72        19
#            2       0.64      0.61      0.62        23
#            3       0.00      0.00      0.00         4
#            5       0.67      0.33      0.44         6
#            6       1.00      1.00      1.00         3
#            7       1.00      0.90      0.95        10
#
#     accuracy                           0.69        65
#    macro avg       0.65      0.62      0.62        65
# weighted avg       0.66      0.69      0.66        65
#
#
# K=7, Metric=euclidean
# Accuracy: 0.6461538461538462
# Report:
#                precision    recall  f1-score   support
#
#            1       0.56      0.79      0.65        19
#            2       0.62      0.65      0.64        23
#            3       0.00      0.00      0.00         4
#            5       1.00      0.17      0.29         6
#            6       1.00      0.67      0.80         3
#            7       0.82      0.90      0.86        10
#
#     accuracy                           0.65        65
#    macro avg       0.67      0.53      0.54        65
# weighted avg       0.65      0.65      0.61        65
#
#
# K=7, Metric=manhattan
# Accuracy: 0.676923076923077
# Report:
#                precision    recall  f1-score   support
#
#            1       0.56      0.95      0.71        19
#            2       0.67      0.52      0.59        23
#            3       0.00      0.00      0.00         4
#            5       1.00      0.33      0.50         6
#            6       0.75      1.00      0.86         3
#            7       1.00      0.90      0.95        10
#
#     accuracy                           0.68        65
#    macro avg       0.66      0.62      0.60        65
# weighted avg       0.68      0.68      0.64        65
#
#
#
# ---- Split: 90-10 ----
#
# K=3, Metric=euclidean
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# K=3, Metric=manhattan
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# K=5, Metric=euclidean
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# K=5, Metric=manhattan
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# K=7, Metric=euclidean
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# K=7, Metric=manhattan
# Accuracy: 1.0
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
#
# ---- Split: 70-30 ----
#
# K=3, Metric=euclidean
# Accuracy: 0.9444444444444444
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89         5
#            2       1.00      1.00      1.00         4
#            3       0.80      1.00      0.89         4
#            4       1.00      1.00      1.00         5
#
#     accuracy                           0.94        18
#    macro avg       0.95      0.95      0.94        18
# weighted avg       0.96      0.94      0.94        18
#
#
# K=3, Metric=manhattan
# Accuracy: 0.7777777777777778
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         5
#            2       0.00      0.00      0.00         4
#            3       1.00      1.00      1.00         4
#            4       0.56      1.00      0.71         5
#
#     accuracy                           0.78        18
#    macro avg       0.64      0.75      0.68        18
# weighted avg       0.65      0.78      0.70        18
#
#
# K=5, Metric=euclidean
# Accuracy: 0.7222222222222222
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89         5
#            2       0.00      0.00      0.00         4
#            3       0.44      1.00      0.62         4
#            4       1.00      1.00      1.00         5
#
#     accuracy                           0.72        18
#    macro avg       0.61      0.70      0.63        18
# weighted avg       0.65      0.72      0.66        18
#
#
# K=5, Metric=manhattan
# Accuracy: 0.7222222222222222
# Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.80      0.89         5
#            2       0.00      0.00      0.00         4
#            3       0.80      1.00      0.89         4
#            4       0.56      1.00      0.71         5
#
#     accuracy                           0.72        18
#    macro avg       0.59      0.70      0.62        18
# weighted avg       0.61      0.72      0.64        18
#
#
# K=7, Metric=euclidean
# Accuracy: 0.6111111111111112
# Report:
#                precision    recall  f1-score   support
#
#            1       0.75      0.60      0.67         5
#            2       0.00      0.00      0.00         4
#            3       0.38      0.75      0.50         4
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.61        18
#    macro avg       0.49      0.59      0.52        18
# weighted avg       0.52      0.61      0.55        18
#
#
# K=7, Metric=manhattan
# Accuracy: 0.6111111111111112
# Report:
#                precision    recall  f1-score   support
#
#            1       0.75      0.60      0.67         5
#            2       0.00      0.00      0.00         4
#            3       0.60      0.75      0.67         4
#            4       0.56      1.00      0.71         5
#
#     accuracy                           0.61        18
#    macro avg       0.48      0.59      0.51        18
# weighted avg       0.50      0.61      0.53        18
